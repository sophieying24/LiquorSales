# %% [markdown]
# # MBA

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import mlxtend as ml
import sqlite3

# %% [markdown]
# ### Querry Data

# %%
conn = sqlite3.connect("data/liquor.db")
query = '''
SELECT Date, t."Store Number", "Store Type", p.product_name, category_new, "Volume Sold", County
FROM transactions AS t
LEFT JOIN stores AS s ON t."Store Number" = s."Store Number"
LEFT JOIN products AS p ON t."Item Number" = p."Item Number"
'''
df = pd.read_sql_query(query, conn)
conn.close()
df.head(3)
# Out:
#                   Date Store Number            Store Type  \
# 0  2012-05-03 00:00:00         2636  Liquor Tobacco Store
# 1  2012-07-05 00:00:00         3735  Liquor Tobacco Store
# 2  2012-03-06 00:00:00         4631                 Other
#
#             product_name category_new  Volume Sold      County
# 0          nikolai vodka        vodka         21.0        polk
# 1  kessler blend whiskey       whisky          1.2    buchanan
# 2          uv cake vodka        vodka          9.0  black hawk

# %%
df.shape
# Out:
# (19445831, 7)

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Store Number            object
# Store Type              object
# product_name            object
# category_new            object
# Volume Sold            float64
# County                  object
# Month                    int64
# dtype: object

# %%
# Make Date column datetime
df.loc[:,'Date']=pd.to_datetime(df.Date)

# %% [markdown]
# ### Subset df by filtering only most popular items and longest running stores

# %%
# Most Popular Items
# Want the top 200 # 9587 Items Total
top200 = df.groupby(['product_name']
                   ).agg({'Volume Sold': 'sum'}
                        ).sort_values(by= 'Volume Sold', 
                                      ascending= False
                                     ).reset_index()[0:200]['product_name'].tolist()

# Get longevity
long_g = df.groupby(['Store Number']
                   ).agg({'Date': (lambda x: (max(x)-min(x)).days)}
                        ).sort_values(by='Date',ascending=False
                                     ).reset_index()
# 3129 Days is the 75% longevity percentile (3163 max). 
# 614 stores out of 2448 stores total will be included in MBA
long_store = long_g.loc[long_g.Date >= 3129]['Store Number'].tolist()

# Filter the popular items and longest running stores
# 5443606 rows × 7 columns
df = df.loc[df['Store Number'].isin(long_store)]
df = df.loc[df['product_name'].isin(top200)]
df.head(3)
# Out:
#         Date Store Number            Store Type          product_name  \
# 0 2012-05-03         2636  Liquor Tobacco Store         nikolai vodka
# 5 2013-08-05         3833           Supermarket  jagermeister liqueur
# 7 2014-04-28         4626     Convenience Store   paramount white rum
#
#   category_new  Volume Sold      County
# 0        vodka         21.0        polk
# 5      liqueur         18.0        cass
# 7          rum          9.0  pottawatta

# %%
df.shape
# Out:
# (7952034, 7)

# %% [markdown]
# ## Make data for MBA R

# %%
## get rid of commas and quotes in product names to avoid complications
df.loc[:,'product_name'] = df.product_name.replace(',','', regex=True)
df.loc[:,'product_name'] = df.product_name.replace("'",'', regex=True)

# %%
df.head(1)
# Out:
#         Date Store Number            Store Type   product_name category_new  \
# 0 2012-05-03         2636  Liquor Tobacco Store  nikolai vodka        vodka
#
#    Volume Sold County
# 0         21.0   polk

# %% [markdown]
# ### General mba for R

# %%
## Groupby and make list of product names for each group
df_gen = df.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_gen[['v' + i for i in map(str, range(1,176))]]= pd.DataFrame(df_gen['product_name'].values.tolist(), index = df_r.index)

## Write to csv for r
#df_r.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_test.csv', index=False)

# Should be 63039 rows and 178 columns
df_r.shape

# %% [markdown]
# ### Supermarket mba for R

# %%
df_groc = df.loc[df['Store Type']=='Supermarket']
df_groc.shape
# Out:
# (4094216, 7)

# %%
## Groupby and make list of product names for each group
df_groc = df.loc[df['Store Type']=='Supermarket']

df_groc = df_groc.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_groc[['v' + i for i in map(str, range(1,176))]]= pd.DataFrame(df_groc['product_name'].values.tolist(), index = df_groc.index)

## Write to csv for r
#df_groc.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_groc.csv', index=False)


df_groc.shape
# Out:
# (27531, 178)

# %% [markdown]
# ### Liquor and Tobacco Store MBA for R

# %%
## Groupby and make list of product names for each group
df_liq = df.loc[df['Store Type']=='Liquor Tobacco Store']

df_liq = df_liq.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_liq[['v' + i for i in map(str, range(1,173))]]= pd.DataFrame(df_liq['product_name'].values.tolist(), index = df_liq.index)

## Write to csv for r
#df_liq.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_liq.csv', index=False)


df_liq.shape
# Out:
# (9929, 175)

# %% [markdown]
# ### Convenience Store MBA for R

# %%
## Groupby and make list of product names for each group
df_con = df.loc[df['Store Type']=='Convenience Store']

df_con = df_con.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_con[['v' + i for i in map(str, range(1,144))]]= pd.DataFrame(df_con['product_name'].values.tolist(), index = df_con.index)

## Write to csv for r
#df_con.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_con.csv', index=False)


df_con.shape
# Out:
# (15785, 146)

# %%
df['Store Type'].unique()
# Out:
# array(['Liquor Tobacco Store', 'Supermarket', 'Convenience Store',
#        'Drug Store', 'Other Grocery or Convenience', 'Other', 'Casino'],
#       dtype=object)

# %% [markdown]
# ### Drug Stores MBA for R

# %%
## Groupby and make list of product names for each group
df_drug = df.loc[df['Store Type']=='Drug Store']

df_drug = df_drug.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_drug[['v' + i for i in map(str, range(1,169))]]= pd.DataFrame(df_drug['product_name'].values.tolist(), index = df_drug.index)

## Write to csv for r
#df_drug.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_drug.csv', index=False)


df_drug.shape
# Out:
# (3280, 171)

# %% [markdown]
# # Seasons

# %%
df['Month'] = pd.DatetimeIndex(df.Date).month

# %%
df.head(1)
# Out:
#         Date Store Number            Store Type   product_name category_new  \
# 0 2012-05-03         2636  Liquor Tobacco Store  nikolai vodka        vodka
#
#    Volume Sold County  Month
# 0         21.0   polk      5

# %% [markdown]
# ### SPRING MBA for R

# %%
df_sp = df.loc[df['Month'].isin([3,4,5])]
df_sp = df_sp.groupby([pd.Grouper(key='Date', freq='M'),
                       'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_sp[['v' + i for i in map(str, range(1,176))]]= pd.DataFrame(df_sp['product_name'].values.tolist(), index = df_sp.index)

## Write to csv for r
# df_sp.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_sp.csv', index=False)


df_sp.shape
# Out:
# (16354, 178)

# %% [markdown]
# ### SUMMER MBA for R

# %%
df_su = df.loc[df['Month'].isin([6,7,8])]
df_su = df_su.groupby([pd.Grouper(key='Date', freq='M'),
                       'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_su[['v' + i for i in map(str, range(1,174))]]= pd.DataFrame(df_su['product_name'].values.tolist(), index = df_su.index)

## Write to csv for r
df_su.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_su.csv', index=False)


df_su.shape
# Out:
# (16380, 176)

# %% [markdown]
# ### FALL MBA for R

# %%
df_fa = df.loc[df['Month'].isin([9,10,11])]
df_fa = df_fa.groupby([pd.Grouper(key='Date', freq='M'),
                       'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_fa[['v' + i for i in map(str, range(1,173))]]= pd.DataFrame(df_fa['product_name'].values.tolist(), index = df_fa.index)

## Write to csv for r
df_fa.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_fa.csv', index=False)


df_fa.shape
# Out:
# (14545, 175)

# %% [markdown]
# ### WINTER MAB for R

# %%
df_wi = df.loc[df['Month'].isin([12,1,2])]
df_wi = df_wi.groupby([pd.Grouper(key='Date', freq='M'),
                       'Store Number']).agg({'product_name':lambda x: list(np.unique(x))}).reset_index()

## Turn list of product names into columns
df_wi[['v' + i for i in map(str, range(1,175))]]= pd.DataFrame(df_wi['product_name'].values.tolist(), index = df_wi.index)

## Write to csv for r
df_wi.drop(['product_name','Store Number', 'Date'], axis=1).to_csv('data/mba_wi.csv', index=False)


df_wi.shape
# Out:
# (15760, 177)

# %% [markdown]
# ## POPULATION

# %%
#df_wi.groupby([pd.Grouper(key='Date', freq='M'),
                     'Store Number']).agg({'product_name':lambda x: len(list(np.unique(x)))}).max()
# Out:
# product_name    174
# dtype: int64

# %% [markdown]
# # PYTHON Overall MBA

# %%
df_all = df[['Date', 'Store Number', 'product_name']].groupby([pd.Grouper(key='Date',
                                freq='M'
                               ),
                     'Store Number',
                     'product_name']
                   ).size().reset_index(name='count')

# %%
df_all['count'].max()
# 37
# Out:
# 37

# %%
df.shape
# Out:
# (7952034, 7)

# %%
basket = (df_all.groupby([pd.Grouper(key='Date', freq='M'),'Store Number','product_name'])['count'].sum().unstack().reset_index().fillna(0)).set_index(['Date','Store Number'])#The encoding function

# %%
basket.head()
# Out:
# product_name             absolut citron (lemon vodka)  \
# Date       Store Number
# 2012-01-31 2106                                   1.0
#            2130                                   1.0
#            2178                                   1.0
#            2190                                  16.0
#            2191                                   3.0
#
# product_name             absolut swedish vodka 80 prf  \
# Date       Store Number
# 2012-01-31 2106                                   3.0
#            2130                                   4.0
#            2178                                   0.0
#            2190                                  23.0
#            2191                                   4.0
#
# product_name             admiral nelson spiced rum  \
# Date       Store Number
# 2012-01-31 2106                                4.0
#            2130                                1.0
#            2178                                0.0
#            2190                                7.0
#            2191                                3.0
#
# product_name             admiral nelson spiced rum traveler  \
# Date       Store Number
# 2012-01-31 2106                                         0.0
#            2130                                         0.0
#            2178                                         0.0
#            2190                                         0.0
#            2191                                         0.0
#
# product_name             ancient age bourbon  arrow peppermint schnapps  \
# Date       Store Number
# 2012-01-31 2106                          0.0                        1.0
#            2130                          0.0                        4.0
#            2178                          1.0                        0.0
#            2190                          2.0                        3.0
#            2191                          3.0                        9.0
#
# product_name             bacardi dragon berry  bacardi gold rum  \
# Date       Store Number
# 2012-01-31 2106                           1.0               0.0
#            2130                           0.0               0.0
#            2178                           1.0               0.0
#            2190                           9.0               9.0
#            2191                           1.0               2.0
#
# product_name             bacardi limon  bacardi superior pet  \
# Date       Store Number
# 2012-01-31 2106                    4.0                   0.0
#            2130                    3.0                   0.0
#            2178                    0.0                   0.0
#            2190                   16.0                   0.0
#            2191                    1.0                   0.0
#
# product_name             bacardi superior rum  bacardi superior rum pet  \
# Date       Store Number
# 2012-01-31 2106                           8.0                       0.0
#            2130                           4.0                       0.0
#            2178                           0.0                       0.0
#            2190                          21.0                       0.0
#            2191                           3.0                       0.0
#
# product_name             bailey's original irish cream  barton gin  \
# Date       Store Number
# 2012-01-31 2106                                    3.0         2.0
#            2130                                    3.0         1.0
#            2178                                    0.0         0.0
#            2190                                   17.0        11.0
#            2191                                    2.0         1.0
#
# product_name             barton rum light  barton vodka  \
# Date       Store Number
# 2012-01-31 2106                       0.0           4.0
#            2130                       0.0           5.0
#            2178                       0.0           0.0
#            2190                      13.0          27.0
#            2191                       0.0           9.0
#
# product_name             beam's 8 star bl whiskey  beefeater gin  \
# Date       Store Number
# 2012-01-31 2106                               0.0            0.0
#            2130                               5.0            0.0
#            2178                               0.0            0.0
#            2190                               9.0            7.0
#            2191                               1.0            1.0
#
# product_name             black velvet  black velvet reserve  \
# Date       Store Number
# 2012-01-31 2106                  10.0                   0.0
#            2130                   6.0                   0.0
#            2178                   2.0                   0.0
#            2190                  24.0                   2.0
#            2191                   4.0                   0.0
#
# product_name             black velvet toasted caramel  black velvet traveler  \
# Date       Store Number
# 2012-01-31 2106                                   0.0                    0.0
#            2130                                   0.0                    0.0
#            2178                                   0.0                    1.0
#            2190                                   0.0                    3.0
#            2191                                   0.0                    0.0
#
# product_name             blue ox vodka  bombay sapphire gin  bulleit bourbon  \
# Date       Store Number
# 2012-01-31 2106                    0.0                  0.0              0.0
#            2130                    0.0                  0.0              0.0
#            2178                    0.0                  0.0              0.0
#            2190                    0.0                 15.0              1.0
#            2191                    0.0                  2.0              0.0
#
# product_name             burnett's vodka 80 prf  caliber vodka  \
# Date       Store Number
# 2012-01-31 2106                             0.0            0.0
#            2130                             0.0            0.0
#            2178                             0.0            0.0
#            2190                             7.0            0.0
#            2191                             0.0            0.0
#
# product_name             canadian club whisky  canadian ltd whisky  \
# Date       Store Number
# 2012-01-31 2106                           3.0                  1.0
#            2130                           3.0                  4.0
#            2178                           0.0                  1.0
#            2190                          11.0                  4.0
#            2191                           3.0                  3.0
#
# product_name             canadian mist canadian why pet  \
# Date       Store Number
# 2012-01-31 2106                                     0.0
#            2130                                     0.0
#            2178                                     1.0
#            2190                                     1.0
#            2191                                     0.0
#
# product_name             canadian reserve whisky  \
# Date       Store Number
# 2012-01-31 2106                              0.0
#            2130                              0.0
#            2178                              0.0
#            2190                              4.0
#            2191                              1.0
#
# product_name             captain morgan 100 proof spiced rum  \
# Date       Store Number
# 2012-01-31 2106                                          0.0
#            2130                                          0.0
#            2178                                          0.0
#            2190                                          3.0
#            2191                                          1.0
#
# product_name             captain morgan long island iced tea  \
# Date       Store Number
# 2012-01-31 2106                                          0.0
#            2130                                          0.0
#            2178                                          0.0
#            2190                                          1.0
#            2191                                          0.0
#
# product_name             captain morgan original spiced  \
# Date       Store Number
# 2012-01-31 2106                                     2.0
#            2130                                     1.0
#            2178                                     0.0
#            2190                                     5.0
#            2191                                     1.0
#
# product_name             captain morgan original spiced rum pet  \
# Date       Store Number
# 2012-01-31 2106                                             0.0
#            2130                                             0.0
#            2178                                             0.0
#            2190                                             5.0
#            2191                                             0.0
#
# product_name             captain morgan spiced barrel  \
# Date       Store Number
# 2012-01-31 2106                                   0.0
#            2130                                   0.0
#            2178                                   0.0
#            2190                                   0.0
#            2191                                   0.0
#
# product_name             captain morgan spiced rum  \
# Date       Store Number
# 2012-01-31 2106                                6.0
#            2130                                6.0
#            2178                                4.0
#            2190                               29.0
#            2191                                0.0
#
# product_name             captain morgan spiced rum pet  \
# Date       Store Number
# 2012-01-31 2106                                    0.0
#            2130                                    0.0
#            2178                                    1.0
#            2190                                    0.0
#            2191                                    1.0
#
# product_name             carolan's irish cream liqueur  castillo silver rum  \
# Date       Store Number
# 2012-01-31 2106                                    1.0                  4.0
#            2130                                    0.0                  2.0
#            2178                                    0.0                  0.0
#            2190                                    7.0                 11.0
#            2191                                    1.0                  2.0
#
# product_name             cedar ridge bourbon  chi-chi's gold margarita  \
# Date       Store Number
# 2012-01-31 2106                          0.0                       0.0
#            2130                          0.0                       0.0
#            2178                          0.0                       0.0
#            2190                          3.0                       0.0
#            2191                          0.0                       0.0
#
# product_name             chi-chi's margarita w/tequila  \
# Date       Store Number
# 2012-01-31 2106                                    0.0
#            2130                                    0.0
#            2178                                    0.0
#            2190                                    1.0
#            2191                                    0.0
#
# product_name             chi-chi's mexican mudslide  christian bros brandy  \
# Date       Store Number
# 2012-01-31 2106                                 0.0                    0.0
#            2130                                 0.0                    1.0
#            2178                                 0.0                    3.0
#            2190                                 0.0                    7.0
#            2191                                 0.0                    2.0
#
# product_name             crown royal  crown royal canadian whisky  \
# Date       Store Number
# 2012-01-31 2106                  2.0                          4.0
#            2130                  1.0                          4.0
#            2178                  0.0                          0.0
#            2190                  0.0                         21.0
#            2191                  0.0                          6.0
#
# product_name             crown royal regal apple  crown royal vanilla  \
# Date       Store Number
# 2012-01-31 2106                              0.0                  0.0
#            2130                              0.0                  0.0
#            2178                              0.0                  0.0
#            2190                              0.0                  0.0
#            2191                              0.0                  0.0
#
# product_name             dekuyper buttershots  dekuyper grape pucker  \
# Date       Store Number
# 2012-01-31 2106                           2.0                    0.0
#            2130                           2.0                    0.0
#            2178                           0.0                    0.0
#            2190                           9.0                   11.0
#            2191                           3.0                    1.0
#
# product_name             dekuyper hot damn!  \
# Date       Store Number
# 2012-01-31 2106                         2.0
#            2130                         3.0
#            2178                         0.0
#            2190                         5.0
#            2191                         5.0
#
# product_name             dekuyper luscious peachtree schnapps  \
# Date       Store Number
# 2012-01-31 2106                                           1.0
#            2130                                           1.0
#            2178                                           0.0
#            2190                                           1.0
#            2191                                           1.0
#
# product_name             dekuyper peachtree  dekuyper sour apple  \
# Date       Store Number
# 2012-01-31 2106                         4.0                  2.0
#            2130                         2.0                  3.0
#            2178                         0.0                  0.0
#            2190                        11.0                  8.0
#            2191                         4.0                  2.0
#
# product_name             dekuyper triple sec  dekuyper watermelon pucker  \
# Date       Store Number
# 2012-01-31 2106                          0.0                         1.0
#            2130                          0.0                         0.0
#            2178                          0.0                         0.0
#            2190                          4.0                        12.0
#            2191                          0.0                         2.0
#
# product_name             desert island long island ice tea cocktail  \
# Date       Store Number
# 2012-01-31 2106                                                 5.0
#            2130                                                 0.0
#            2178                                                 0.0
#            2190                                                 6.0
#            2191                                                 0.0
#
# product_name             dewars white label scotch  disaronno amaretto  \
# Date       Store Number
# 2012-01-31 2106                                0.0                 0.0
#            2130                                1.0                 1.0
#            2178                                0.0                 1.0
#            2190                               13.0                 3.0
#            2191                                2.0                 2.0
#
# product_name             dr. mcgillicuddy's cherry schnapps  \
# Date       Store Number
# 2012-01-31 2106                                         7.0
#            2130                                         6.0
#            2178                                         7.0
#            2190                                         1.0
#            2191                                         8.0
#
# product_name             dr. mcgillicuddy's mentholmint  e & j vs  \
# Date       Store Number
# 2012-01-31 2106                                     3.0       1.0
#            2130                                     1.0       1.0
#            2178                                     1.0       0.0
#            2190                                     3.0       2.0
#            2191                                     0.0       0.0
#
# product_name             e & j vs brandy  e & j vsop superior reserve  \
# Date       Store Number
# 2012-01-31 2106                      0.0                          0.0
#            2130                      1.0                          0.0
#            2178                      0.0                          1.0
#            2190                      4.0                          5.0
#            2191                      0.0                          1.0
#
# product_name             evan williams str bourbon  \
# Date       Store Number
# 2012-01-31 2106                                0.0
#            2130                                0.0
#            2178                                0.0
#            2190                                3.0
#            2191                                1.0
#
# product_name             evan williams yr str bourbon  everclear alcohol  \
# Date       Store Number
# 2012-01-31 2106                                   0.0                0.0
#            2130                                   0.0                1.0
#            2178                                   0.0                0.0
#            2190                                   1.0                2.0
#            2191                                   0.0                0.0
#
# product_name             fireball cinnamon  fireball cinnamon whiskey  \
# Date       Store Number
# 2012-01-31 2106                        0.0                        2.0
#            2130                        0.0                        1.0
#            2178                        0.0                        1.0
#            2190                        0.0                       16.0
#            2191                        0.0                        2.0
#
# product_name             fireball cinnamon whiskey mini dispenser  \
# Date       Store Number
# 2012-01-31 2106                                               0.0
#            2130                                               0.0
#            2178                                               0.0
#            2190                                               0.0
#            2191                                               0.0
#
# product_name             fireball cinnamon whiskey pet  \
# Date       Store Number
# 2012-01-31 2106                                    0.0
#            2130                                    0.0
#            2178                                    0.0
#            2190                                    0.0
#            2191                                    0.0
#
# product_name             fireball cinnamon whisky  five o'clock gin  \
# Date       Store Number
# 2012-01-31 2106                               0.0               3.0
#            2130                               0.0               4.0
#            2178                               0.0               0.0
#            2190                               0.0               4.0
#            2191                               0.0               3.0
#
# product_name             five o'clock pet vodka  five o'clock vodka  \
# Date       Store Number
# 2012-01-31 2106                             0.0                 9.0
#            2130                             0.0                 9.0
#            2178                             1.0                 2.0
#            2190                             2.0                 3.0
#            2191                             0.0                12.0
#
# product_name             five star  five star pet  fleischmann's gin  \
# Date       Store Number
# 2012-01-31 2106                6.0            0.0                0.0
#            2130                5.0            0.0                1.0
#            2178                2.0            0.0                1.0
#            2190                7.0            0.0                3.0
#            2191                3.0            0.0                0.0
#
# product_name             fleischmann's royal vodka  \
# Date       Store Number
# 2012-01-31 2106                                0.0
#            2130                                0.0
#            2178                                2.0
#            2190                                0.0
#            2191                                0.0
#
# product_name             fleischmann's royal vodka 80 prf  fris danish vodka  \
# Date       Store Number
# 2012-01-31 2106                                       0.0                0.0
#            2130                                       0.0                0.0
#            2178                                       0.0                0.0
#            2190                                       3.0                4.0
#            2191                                       0.0                1.0
#
# product_name             gilbey's gin london dry  glenlivet 12 yr malt scotch  \
# Date       Store Number
# 2012-01-31 2106                              0.0                          0.0
#            2130                              1.0                          0.0
#            2178                              0.0                          0.0
#            2190                              2.0                          6.0
#            2191                              0.0                          3.0
#
# product_name             gordon's gin london dry - pet  \
# Date       Store Number
# 2012-01-31 2106                                    0.0
#            2130                                    0.0
#            2178                                    0.0
#            2190                                    0.0
#            2191                                    0.0
#
# product_name             grangala triple orange liqueur  grey goose vodka  \
# Date       Store Number
# 2012-01-31 2106                                     0.0               7.0
#            2130                                     0.0               9.0
#            2178                                     0.0               2.0
#            2190                                     7.0              23.0
#            2191                                     1.0               5.0
#
# product_name             hawkeye blend whiskey  hawkeye gin  \
# Date       Store Number
# 2012-01-31 2106                            1.0          0.0
#            2130                            0.0          0.0
#            2178                            0.0          2.0
#            2190                            5.0          8.0
#            2191                            4.0          0.0
#
# product_name             hawkeye light rum  hawkeye vodka  hennessy vs  \
# Date       Store Number
# 2012-01-31 2106                        0.0            4.0          0.0
#            2130                        0.0            2.0          0.0
#            2178                        0.0            1.0          0.0
#            2190                        4.0           23.0          0.0
#            2191                        1.0           10.0          0.0
#
# product_name             hennessy vs cognac  jack daniel's tennessee fire  \
# Date       Store Number
# 2012-01-31 2106                         1.0                           0.0
#            2130                         3.0                           0.0
#            2178                         1.0                           0.0
#            2190                        14.0                           0.0
#            2191                         3.0                           0.0
#
# product_name             jack daniel's tennessee honey  \
# Date       Store Number
# 2012-01-31 2106                                    0.0
#            2130                                    2.0
#            2178                                    1.0
#            2190                                    3.0
#            2191                                    0.0
#
# product_name             jack daniels old #7 black lbl  jagermeister liqueur  \
# Date       Store Number
# 2012-01-31 2106                                    4.0                   7.0
#            2130                                    4.0                   3.0
#            2178                                    1.0                   2.0
#            2190                                   20.0                  16.0
#            2191                                    6.0                   6.0
#
# product_name             jameson  jeremiah weed sweet tea vodka  jim beam  \
# Date       Store Number
# 2012-01-31 2106              4.0                            3.0       5.0
#            2130              2.0                            1.0       3.0
#            2178              0.0                            1.0       2.0
#            2190             24.0                           11.0      19.0
#            2191              4.0                            5.0      10.0
#
# product_name             jim beam apple  johnnie walker black  \
# Date       Store Number
# 2012-01-31 2106                     0.0                   0.0
#            2130                     0.0                   0.0
#            2178                     0.0                   0.0
#            2190                     0.0                   3.0
#            2191                     0.0                   3.0
#
# product_name             johnnie walker red  \
# Date       Store Number
# 2012-01-31 2106                         0.0
#            2130                         0.0
#            2178                         0.0
#            2190                         5.0
#            2191                         0.0
#
# product_name             jose cuervo authentic light margarita lime  \
# Date       Store Number
# 2012-01-31 2106                                                 0.0
#            2130                                                 0.0
#            2178                                                 0.0
#            2190                                                 0.0
#            2191                                                 0.0
#
# product_name             jose cuervo authentic lime margarita  \
# Date       Store Number
# 2012-01-31 2106                                           0.0
#            2130                                           2.0
#            2178                                           0.0
#            2190                                           0.0
#            2191                                           0.0
#
# product_name             jose cuervo authentic strawberry margarita  \
# Date       Store Number
# 2012-01-31 2106                                                 0.0
#            2130                                                 0.0
#            2178                                                 0.0
#            2190                                                 0.0
#            2191                                                 4.0
#
# product_name             jose cuervo especial reposado tequila  \
# Date       Store Number
# 2012-01-31 2106                                            5.0
#            2130                                            4.0
#            2178                                            1.0
#            2190                                           20.0
#            2191                                            8.0
#
# product_name             jose cuervo especial silver  \
# Date       Store Number
# 2012-01-31 2106                                  0.0
#            2130                                  0.0
#            2178                                  0.0
#            2190                                  3.0
#            2191                                  0.0
#
# product_name             jose cuervo golden margarita  \
# Date       Store Number
# 2012-01-31 2106                                   0.0
#            2130                                   0.0
#            2178                                   0.0
#            2190                                   0.0
#            2191                                   0.0
#
# product_name             jose cuervo mango margarita  juarez gold dss  \
# Date       Store Number
# 2012-01-31 2106                                  0.0              0.0
#            2130                                  0.0              0.0
#            2178                                  0.0              0.0
#            2190                                  0.0              9.0
#            2191                                  0.0              5.0
#
# product_name             juarez tequila gold  juarez tequila silver  \
# Date       Store Number
# 2012-01-31 2106                          0.0                    0.0
#            2130                          0.0                    1.0
#            2178                          0.0                    0.0
#            2190                         13.0                    2.0
#            2191                          1.0                    6.0
#
# product_name             juarez triple sec  kahlua coffee liqueur  \
# Date       Store Number
# 2012-01-31 2106                        1.0                    4.0
#            2130                        0.0                    2.0
#            2178                        0.0                    1.0
#            2190                       12.0                   13.0
#            2191                        5.0                    1.0
#
# product_name             kessler blend whiskey  ketel one imported vodka  \
# Date       Store Number
# 2012-01-31 2106                            0.0                       2.0
#            2130                            4.0                       1.0
#            2178                            1.0                       0.0
#            2190                            7.0                      20.0
#            2191                            8.0                       1.0
#
# product_name             kinky blue  kinky liqueur  \
# Date       Store Number
# 2012-01-31 2106                 0.0            4.0
#            2130                 0.0            2.0
#            2178                 0.0            1.0
#            2190                 0.0            4.0
#            2191                 0.0            0.0
#
# product_name             kirkland premium golden margarita  \
# Date       Store Number
# 2012-01-31 2106                                        0.0
#            2130                                        0.0
#            2178                                        0.0
#            2190                                        0.0
#            2191                                        0.0
#
# product_name             kirkland signature american vodka  korski vodka  \
# Date       Store Number
# 2012-01-31 2106                                        0.0           0.0
#            2130                                        0.0           0.0
#            2178                                        0.0           0.0
#            2190                                        0.0           4.0
#            2191                                        0.0           0.0
#
# product_name             kraken black spiced rum  lady bligh spiced rum  \
# Date       Store Number
# 2012-01-31 2106                              1.0                    1.0
#            2130                              0.0                    0.0
#            2178                              0.0                    0.0
#            2190                              2.0                    3.0
#            2191                              0.0                    0.0
#
# product_name             lauder's  maker's mark  malibu coconut rum  \
# Date       Store Number
# 2012-01-31 2106               0.0           1.0                 4.0
#            2130               1.0           0.0                 2.0
#            2178               1.0           1.0                 1.0
#            2190              12.0          18.0                16.0
#            2191               2.0           1.0                 6.0
#
# product_name             mccormick vodka  mccormick vodka pet  \
# Date       Store Number
# 2012-01-31 2106                      0.0                  4.0
#            2130                      1.0                  4.0
#            2178                      0.0                  2.0
#            2190                      4.0                 11.0
#            2191                      0.0                  1.0
#
# product_name             member's mark spiced rum  members mark vodka  \
# Date       Store Number
# 2012-01-31 2106                               0.0                 0.0
#            2130                               0.0                 0.0
#            2178                               0.0                 0.0
#            2190                               0.0                 0.0
#            2191                               0.0                 0.0
#
# product_name             montezuma gold tequila  montezuma triple sec  \
# Date       Store Number
# 2012-01-31 2106                             0.0                   0.0
#            2130                             0.0                   0.0
#            2178                             0.0                   0.0
#            2190                             8.0                   6.0
#            2191                             0.0                   0.0
#
# product_name             new amsterdam gin  new amsterdam peach  \
# Date       Store Number
# 2012-01-31 2106                        0.0                  0.0
#            2130                        3.0                  0.0
#            2178                        0.0                  0.0
#            2190                        2.0                  0.0
#            2191                        0.0                  0.0
#
# product_name             new amsterdam pineapple  new amsterdam red berry  \
# Date       Store Number
# 2012-01-31 2106                              0.0                      0.0
#            2130                              0.0                      0.0
#            2178                              0.0                      0.0
#            2190                              0.0                      0.0
#            2191                              0.0                      0.0
#
# product_name             new amsterdam vodka  nikolai vodka  old crow  \
# Date       Store Number
# 2012-01-31 2106                          0.0            0.0       0.0
#            2130                          0.0            0.0       0.0
#            2178                          0.0            2.0       0.0
#            2190                          0.0            5.0       5.0
#            2191                          0.0            0.0       2.0
#
# product_name             paramount amaretto  \
# Date       Store Number
# 2012-01-31 2106                         4.0
#            2130                         3.0
#            2178                         1.0
#            2190                        12.0
#            2191                         2.0
#
# product_name             paramount apricot flavored brandy  \
# Date       Store Number
# 2012-01-31 2106                                        0.0
#            2130                                        0.0
#            2178                                        1.0
#            2190                                        4.0
#            2191                                        1.0
#
# product_name             paramount blackberry brandy  paramount gin  \
# Date       Store Number
# 2012-01-31 2106                                  0.0            1.0
#            2130                                  2.0            3.0
#            2178                                  1.0            0.0
#            2190                                  6.0            9.0
#            2191                                  0.0            0.0
#
# product_name             paramount gold rum  paramount peppermint schnapps  \
# Date       Store Number
# 2012-01-31 2106                         0.0                            1.0
#            2130                         0.0                            0.0
#            2178                         0.0                            0.0
#            2190                         6.0                           10.0
#            2191                         4.0                            1.0
#
# product_name             paramount triple sec  paramount white rum  \
# Date       Store Number
# 2012-01-31 2106                           0.0                  4.0
#            2130                           0.0                  1.0
#            2178                           0.0                  3.0
#            2190                           1.0                 18.0
#            2191                           0.0                  6.0
#
# product_name             paramount white rum traveler  patron tequila silver  \
# Date       Store Number
# 2012-01-31 2106                                   0.0                    2.0
#            2130                                   0.0                    2.0
#            2178                                   0.0                    0.0
#            2190                                   3.0                   13.0
#            2191                                   0.0                    2.0
#
# product_name             paul masson grande amber brandy  phillips vodka  \
# Date       Store Number
# 2012-01-31 2106                                      0.0             0.0
#            2130                                      5.0             2.0
#            2178                                      0.0             0.0
#            2190                                     12.0            23.0
#            2191                                      5.0             0.0
#
# product_name             phillips vodka ez pack  phillips white rum  \
# Date       Store Number
# 2012-01-31 2106                             0.0                 0.0
#            2130                             0.0                 0.0
#            2178                             0.0                 0.0
#            2190                             0.0                13.0
#            2191                             0.0                 0.0
#
# product_name             pinnacle vodka  platinum 7x vodka  \
# Date       Store Number
# 2012-01-31 2106                     0.0                0.0
#            2130                     0.0                0.0
#            2178                     0.0                0.0
#            2190                     3.0                0.0
#            2191                     0.0                0.0
#
# product_name             popov vodka 80 prf  red stag black cherry  \
# Date       Store Number
# 2012-01-31 2106                         0.0                    1.0
#            2130                         0.0                    1.0
#            2178                         1.0                    1.0
#            2190                         4.0                    2.0
#            2191                         2.0                    2.0
#
# product_name             remy martin vsop  rich & rare canadian whisky  \
# Date       Store Number
# 2012-01-31 2106                       0.0                          0.0
#            2130                       0.0                          0.0
#            2178                       0.0                          0.0
#            2190                       4.0                          0.0
#            2191                       4.0                          0.0
#
# product_name             rumchata  rumple minze peppermint schnapps liqueur  \
# Date       Store Number
# 2012-01-31 2106               3.0                                       8.0
#            2130               1.0                                       4.0
#            2178               2.0                                       2.0
#            2190               5.0                                      15.0
#            2191               2.0                                       5.0
#
# product_name             ryan's cream liqueur  sailor jerry spiced navy rum  \
# Date       Store Number
# 2012-01-31 2106                           1.0                           1.0
#            2130                           0.0                           0.0
#            2178                           0.0                           1.0
#            2190                           5.0                           5.0
#            2191                           0.0                           0.0
#
# product_name             sauza gold  scoresby rare scotch  \
# Date       Store Number
# 2012-01-31 2106                 2.0                   0.0
#            2130                 0.0                   0.0
#            2178                 0.0                   0.0
#            2190                10.0                   9.0
#            2191                 0.0                   1.0
#
# product_name             seagrams 7 crown bl whiskey  seagrams extra dry gin  \
# Date       Store Number
# 2012-01-31 2106                                  4.0                     0.0
#            2130                                  3.0                     2.0
#            2178                                  3.0                     3.0
#            2190                                 19.0                     9.0
#            2191                                  9.0                     0.0
#
# product_name             seagrams v.o. bl canadian whisky pet  seagrams vodka  \
# Date       Store Number
# 2012-01-31 2106                                           0.0             0.0
#            2130                                           0.0             0.0
#            2178                                           0.0             0.0
#            2190                                           0.0             2.0
#            2191                                           0.0             0.0
#
# product_name             skol vodka  skyy vodka  smirnoff 80prf  \
# Date       Store Number
# 2012-01-31 2106                 2.0         0.0             0.0
#            2130                 0.0         0.0             1.0
#            2178                 0.0         1.0             0.0
#            2190                 4.0         6.0             2.0
#            2191                 0.0         0.0             0.0
#
# product_name             smirnoff raspberry  smirnoff vodka 80 prf  \
# Date       Store Number
# 2012-01-31 2106                         0.0                    3.0
#            2130                         0.0                    5.0
#            2178                         0.0                    1.0
#            2190                         0.0                   16.0
#            2191                         0.0                    2.0
#
# product_name             smirnoff vodka 80 prf pet  smirnoff vodka traveller  \
# Date       Store Number
# 2012-01-31 2106                                0.0                       0.0
#            2130                                0.0                       0.0
#            2178                                0.0                       0.0
#            2190                                3.0                       3.0
#            2191                                0.0                       0.0
#
# product_name             sobieski vodka  southern comfort  \
# Date       Store Number
# 2012-01-31 2106                     0.0               4.0
#            2130                     0.0               2.0
#            2178                     1.0               1.0
#            2190                     1.0              12.0
#            2191                     0.0               5.0
#
# product_name             southern comfort pet  sunny brook blend whiskey  \
# Date       Store Number
# 2012-01-31 2106                           0.0                        0.0
#            2130                           0.0                        0.0
#            2178                           1.0                        0.0
#            2190                           4.0                        2.0
#            2191                           1.0                        0.0
#
# product_name             svedka vodka  tanqueray gin  templeton rye  ten high  \
# Date       Store Number
# 2012-01-31 2106                   0.0            1.0            2.0       3.0
#            2130                   0.0            1.0            0.0       1.0
#            2178                   0.0            1.0            0.0       0.0
#            2190                   9.0           22.0            3.0      15.0
#            2191                   0.0            2.0            0.0       4.0
#
# product_name             tequila rose liqueur  titos handmade vodka  \
# Date       Store Number
# 2012-01-31 2106                           1.0                   0.0
#            2130                           2.0                   0.0
#            2178                           0.0                   0.0
#            2190                           5.0                   2.0
#            2191                           1.0                   0.0
#
# product_name             tortilla gold dss  tortilla white tequila  \
# Date       Store Number
# 2012-01-31 2106                        0.0                     2.0
#            2130                        0.0                     1.0
#            2178                        0.0                     0.0
#            2190                        0.0                     8.0
#            2191                        0.0                     1.0
#
# product_name             uv blue (raspberry) vodka  uv cake vodka  \
# Date       Store Number
# 2012-01-31 2106                                3.0            2.0
#            2130                                4.0            1.0
#            2178                                2.0            1.0
#            2190                               12.0            6.0
#            2191                                4.0            3.0
#
# product_name             uv grape vodka  uv red (cherry) vodka  uv vodka  \
# Date       Store Number
# 2012-01-31 2106                     1.0                    0.0       0.0
#            2130                     0.0                    0.0       0.0
#            2178                     0.0                    0.0       0.0
#            2190                    13.0                   10.0       4.0
#            2191                     0.0                    3.0       0.0
#
# product_name             uv vodka pet  wild turkey 101  \
# Date       Store Number
# 2012-01-31 2106                   0.0              1.0
#            2130                   0.0              0.0
#            2178                   0.0              0.0
#            2190                   0.0              4.0
#            2191                   0.0              2.0
#
# product_name             wild turkey american honey  windsor canadian  \
# Date       Store Number
# 2012-01-31 2106                                 0.0               1.0
#            2130                                 1.0               0.0
#            2178                                 1.0               1.0
#            2190                                 1.0               3.0
#            2191                                 0.0               1.0
#
# product_name             windsor canadian pet  yukon jack canadian liqueur
# Date       Store Number
# 2012-01-31 2106                           0.0                          3.0
#            2130                           0.0                          1.0
#            2178                           0.0                          1.0
#            2190                           2.0                         10.0
#            2191                           1.0                          4.0

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket.applymap(encode_units)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.5, use_colnames=True, max_len=2)

# %%
frequent_itemsets.head()
# Out:
#     support                         itemsets
# 0  0.708292   (absolut swedish vodka 80 prf)
# 1  0.700455      (admiral nelson spiced rum)
# 2  0.412380                  (bacardi limon)
# 3  0.710417           (bacardi superior rum)
# 4  0.439522  (bailey's original irish cream)

# %%
rules = association_rules(frequent_itemsets, metric="lift")
# rules.sort_values('confidence', ascending = False, inplace = True)
# rules.head(10)

# %%
rules.sort_values('confidence', ascending = False, inplace = True)
rules.shape
# Out:
# (260, 9)

# %% [markdown]
# - Note: Hawkeye brand made in Missouri marketed towards residents of Iowa, which is known as "the Hawkeye State". Products sold under the Hawkeye name include blended whiskey, rum, gin, flavored vodka, and the most popular product – vodka
# - Black Velvet (whiskey) is the most popular alcohol in iowa

# %%
rules.loc[(rules.confidence >.90)&(rules.support >.55)].sort_values('lift', ascending = False)
# Out:
#                                  antecedents      consequents  \
# 204                    (paramount white rum)  (hawkeye vodka)
# 40               (admiral nelson spiced rum)  (hawkeye vodka)
# 203                     (malibu coconut rum)  (hawkeye vodka)
# 215              (uv blue (raspberry) vodka)  (hawkeye vodka)
# 200  (jose cuervo especial reposado tequila)  (hawkeye vodka)
# 209                  (smirnoff vodka 80 prf)  (hawkeye vodka)
# 12            (absolut swedish vodka 80 prf)  (hawkeye vodka)
# 64                    (bacardi superior rum)  (hawkeye vodka)
# 167              (fireball cinnamon whiskey)  (hawkeye vodka)
# 196                   (jagermeister liqueur)  (hawkeye vodka)
# 85                     (canadian ltd whisky)   (black velvet)
# 121                       (southern comfort)   (black velvet)
# 105                   (jagermeister liqueur)   (black velvet)
# 33               (admiral nelson spiced rum)   (black velvet)
# 115                    (paramount white rum)   (black velvet)
# 93             (crown royal canadian whisky)   (black velvet)
# 95               (fireball cinnamon whiskey)   (black velvet)
# 116            (seagrams 7 crown bl whiskey)   (black velvet)
# 119                  (smirnoff vodka 80 prf)   (black velvet)
# 125              (uv blue (raspberry) vodka)   (black velvet)
# 56                    (bacardi superior rum)   (black velvet)
# 113                     (malibu coconut rum)   (black velvet)
# 89               (captain morgan spiced rum)   (black velvet)
# 101                          (hawkeye vodka)   (black velvet)
# 110  (jose cuervo especial reposado tequila)   (black velvet)
# 87          (captain morgan original spiced)   (black velvet)
# 97                      (five o'clock vodka)   (black velvet)
# 109                               (jim beam)   (black velvet)
# 102          (jack daniels old #7 black lbl)   (black velvet)
# 5             (absolut swedish vodka 80 prf)   (black velvet)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 204            0.638763            0.850981  0.596916    0.934487  1.098129
# 40             0.700455            0.850981  0.650153    0.928186  1.090725
# 203            0.639826            0.850981  0.587446    0.918134  1.078912
# 215            0.647187            0.850981  0.589048    0.910167  1.069550
# 200            0.621504            0.850981  0.564698    0.908599  1.067708
# 209            0.666857            0.850981  0.601548    0.902065  1.060029
# 12             0.708292            0.850981  0.638446    0.901389  1.059234
# 64             0.710417            0.850981  0.640254    0.901237  1.059056
# 167            0.685703            0.850981  0.617871    0.901078  1.058870
# 196            0.613144            0.850981  0.551992    0.900264  1.057913
# 85             0.576706            0.939101  0.559733    0.970568  1.033507
# 121            0.600834            0.939101  0.579974    0.965281  1.027878
# 105            0.613144            0.939101  0.591761    0.965125  1.027711
# 33             0.700455            0.939101  0.675851    0.964875  1.027445
# 115            0.638763            0.939101  0.615762    0.963990  1.026503
# 93             0.592237            0.939101  0.570361    0.963063  1.025516
# 95             0.685703            0.939101  0.660321    0.962985  1.025433
# 116            0.782246            0.939101  0.753185    0.962849  1.025288
# 119            0.666857            0.939101  0.641286    0.961654  1.024015
# 125            0.647187            0.939101  0.622234    0.961444  1.023792
# 56             0.710417            0.939101  0.682990    0.961392  1.023737
# 113            0.639826            0.939101  0.615064    0.961298  1.023636
# 89             0.754565            0.939101  0.724663    0.960372  1.022650
# 101            0.850981            0.939101  0.817256    0.960369  1.022647
# 110            0.621504            0.939101  0.596647    0.960004  1.022258
# 87             0.576786            0.939101  0.552991    0.958746  1.020919
# 97             0.715795            0.939101  0.686242    0.958713  1.020883
# 109            0.730706            0.939101  0.700503    0.958665  1.020833
# 102            0.732689            0.939101  0.701915    0.957998  1.020122
# 5              0.708292            0.939101  0.678421    0.957828  1.019941
#
#      leverage  conviction
# 204  0.053341    2.274656
# 40   0.054079    2.075079
# 203  0.042966    1.820269
# 215  0.038304    1.658846
# 200  0.035810    1.630385
# 209  0.034065    1.521607
# 12   0.035703    1.511172
# 64   0.035703    1.508854
# 167  0.034352    1.506429
# 196  0.030217    1.494132
# 85   0.018147    2.069137
# 121  0.015730    1.754071
# 105  0.015956    1.746188
# 33   0.018053    1.733751
# 115  0.015898    1.691181
# 93   0.014191    1.648728
# 95   0.016377    1.645257
# 116  0.018576    1.639215
# 119  0.015039    1.588129
# 125  0.014460    1.579498
# 56   0.015836    1.577381
# 113  0.014202    1.573538
# 89   0.016050    1.536750
# 101  0.018099    1.536649
# 110  0.012991    1.522626
# 87   0.011331    1.476187
# 97   0.014038    1.475006
# 109  0.014296    1.473310
# 102  0.013845    1.449894
# 5    0.013264    1.444042

# %% [markdown]
# ## Store Type

# %%
def mba_org(store_t, df1=df, min_s=0.5, max_l=2):
    df = df1.loc[df1['Store Type']==store_t].groupby([pd.Grouper(key='Date',freq='M'),'Store Number','product_name']).size().reset_index(name='count')

    basket = (df.groupby([pd.Grouper(key='Date', 
                                               freq='M'
                                              ),
                                    'Store Number',
                                    'product_name'
                                   ])['count'].sum().unstack().reset_index().fillna(0)).set_index(['Date',
                                                                                                   'Store Number'])

    basket_sets = basket.applymap(encode_units)

    frequent_itemsets = apriori(basket_sets, min_support=min_s, use_colnames=True, max_len=max_l)

    rules = association_rules(frequent_itemsets, metric="lift")
    
    return rules, frequent_itemsets

# %% [markdown]
# #### Define function to filter for store type and season and run mba

# %%
def mba(store_t=None, season=None, df1=df, min_s=0.5, max_l=2):
    if store_t == None:
        df = df1.loc[df1['Month'].isin(season)
                        ].groupby([pd.Grouper(key='Date',
                                              freq='M'
                                             ),
                                   'Store Number',
                                   'product_name'
                                  ]).size().reset_index(name='count')
        print('Season')
    elif season == None:
        df = df1.loc[df1['Store Type']==store_t
                    ].groupby([pd.Grouper(key='Date',
                                          freq='M'
                                         ),
                               'Store Number',
                               'product_name'
                              ]).size().reset_index(name='count')
        print('Store Type')
    else:
        return None

    basket = (df.groupby([pd.Grouper(key='Date', 
                                               freq='M'
                                              ),
                                    'Store Number',
                                    'product_name'
                                   ])['count'].sum().unstack().reset_index().fillna(0)).set_index(['Date',
                                                                                                   'Store Number'])

    basket_sets = basket.applymap(encode_units)

    frequent_itemsets = apriori(basket_sets, min_support=min_s, use_colnames=True, max_len=max_l)

    rules = association_rules(frequent_itemsets, metric="lift")
    
    return rules, frequent_itemsets

# %%
df.loc[df['Store Type']=='Supermarket'].shape
# Out:
# (4094216, 7)

# %%
df.loc[df['Store Type']=='Liquor Tobacco Store'].shape
# Out:
# (2030640, 7)

# %%
df.loc[df['Store Type']=='Convenience Store'].shape
# Out:
# (778505, 7)

# %%
df.loc[df['Store Type']=='Drug Store'].shape
# Out:
# (535619, 7)

# %%
df.loc[df['Store Type']=='Casino'].shape
# Out:
# (16073, 7)

# %% [markdown]
# #### SUPERMARKETS

# %%
rules_groc, frequent_itemsets_groc = mba(store_t='Supermarket')
rules_groc.loc[(rules_groc.confidence >.90)&(rules_groc.support >.55)].sort_values('lift', ascending = False).head(20)
# Out:
# Store Type
#                                  antecedents                    consequents  \
# 429                   (jagermeister liqueur)  (seagrams 7 crown bl whiskey)
# 511                               (ten high)  (seagrams 7 crown bl whiskey)
# 459   (jose cuervo authentic lime margarita)  (seagrams 7 crown bl whiskey)
# 501                         (phillips vodka)  (seagrams 7 crown bl whiskey)
# 469  (jose cuervo especial reposado tequila)  (seagrams 7 crown bl whiskey)
# 491                    (paramount white rum)  (seagrams 7 crown bl whiskey)
# 515              (uv blue (raspberry) vodka)  (seagrams 7 crown bl whiskey)
# 341                              (five star)  (seagrams 7 crown bl whiskey)
# 477                     (malibu coconut rum)  (seagrams 7 crown bl whiskey)
# 77               (admiral nelson spiced rum)  (seagrams 7 crown bl whiskey)
# 121                   (bacardi superior rum)  (seagrams 7 crown bl whiskey)
# 445                               (jim beam)  (seagrams 7 crown bl whiskey)
# 221                    (canadian ltd whisky)  (seagrams 7 crown bl whiskey)
# 283              (fireball cinnamon whiskey)  (seagrams 7 crown bl whiskey)
# 505                  (smirnoff vodka 80 prf)  (seagrams 7 crown bl whiskey)
# 33            (absolut swedish vodka 80 prf)  (seagrams 7 crown bl whiskey)
# 368                          (paramount gin)                (hawkeye vodka)
# 384                           (svedka vodka)                (hawkeye vodka)
# 376                               (rumchata)                (hawkeye vodka)
# 330                              (five star)                (hawkeye vodka)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 429            0.604863            0.855349  0.559048    0.924256  1.080561
# 511            0.605790            0.855349  0.556057    0.917905  1.073136
# 459            0.665421            0.855349  0.607943    0.913622  1.068128
# 501            0.616406            0.855349  0.562248    0.912139  1.066394
# 469            0.682885            0.855349  0.622118    0.911014  1.065079
# 491            0.765394            0.855349  0.694967    0.907986  1.061539
# 515            0.738180            0.855349  0.670176    0.907876  1.061410
# 341            0.634708            0.855349  0.576004    0.907510  1.060983
# 477            0.747271            0.855349  0.676486    0.905275  1.058369
# 77             0.779389            0.855349  0.703669    0.902847  1.055531
# 121            0.761685            0.855349  0.687521    0.902631  1.055278
# 445            0.758605            0.855349  0.684530    0.902353  1.054954
# 221            0.665540            0.855349  0.600496    0.902269  1.054856
# 283            0.701426            0.855349  0.632106    0.901172  1.053573
# 505            0.713179            0.855349  0.642334    0.900663  1.052977
# 33             0.758097            0.855349  0.682437    0.900197  1.052433
# 368            0.575795            0.916594  0.554413    0.962865  1.050481
# 384            0.584228            0.916594  0.561919    0.961814  1.049334
# 376            0.578606            0.916594  0.553844    0.957205  1.044306
# 330            0.634708            0.916594  0.606986    0.956323  1.043344
#
#      leverage  conviction
# 429  0.041679    1.909739
# 511  0.037896    1.761999
# 459  0.038776    1.674630
# 501  0.035006    1.646359
# 469  0.038013    1.625549
# 491  0.040289    1.572063
# 515  0.038774    1.570174
# 341  0.033108    1.563975
# 477  0.037308    1.527060
# 77   0.037020    1.488905
# 121  0.036014    1.485594
# 445  0.035658    1.481378
# 221  0.031228    1.480100
# 283  0.032142    1.463676
# 505  0.032317    1.456162
# 33   0.034000    1.449373
# 368  0.026642    2.246002
# 384  0.026419    2.184198
# 376  0.023497    1.948951
# 330  0.025216    1.909601

# %%
frequent_itemsets_groc.sort_values(by='support', ascending=False).head(20)
# Out:
#       support                                       itemsets
# 4    0.933610                                 (black velvet)
# 17   0.916594                                (hawkeye vodka)
# 120  0.867490                  (black velvet, hawkeye vodka)
# 33   0.855349                  (seagrams 7 crown bl whiskey)
# 14   0.829810                           (five o'clock vodka)
# 136  0.814199    (seagrams 7 crown bl whiskey, black velvet)
# 232  0.804031   (seagrams 7 crown bl whiskey, hawkeye vodka)
# 117  0.788092             (black velvet, five o'clock vodka)
# 1    0.779389                    (admiral nelson spiced rum)
# 18   0.778462                (jack daniels old #7 black lbl)
# 189  0.777774            (five o'clock vodka, hawkeye vodka)
# 30   0.765394                          (paramount white rum)
# 2    0.761685                         (bacardi superior rum)
# 21   0.758605                                     (jim beam)
# 0    0.758097                 (absolut swedish vodka 80 prf)
# 121  0.747391  (jack daniels old #7 black lbl, black velvet)
# 25   0.747271                           (malibu coconut rum)
# 64   0.743952      (black velvet, admiral nelson spiced rum)
# 71   0.739047     (admiral nelson spiced rum, hawkeye vodka)
# 42   0.738180                    (uv blue (raspberry) vodka)

# %% [markdown]
# #### LIQUOR STORES

# %%
rules_liq, frequent_itemsets_liq = mba(store_t='Liquor Tobacco Store')
rules_liq.loc[(rules_liq.confidence >.90)&(rules_liq.support >.55)].sort_values('lift', ascending = False).head(20)
# Out:
# Season
#                                  antecedents                      consequents  \
# 267     (dr. mcgillicuddy's cherry schnapps)  (jack daniels old #7 black lbl)
# 411                     (malibu coconut rum)  (jack daniels old #7 black lbl)
# 307                              (five star)             (five o'clock vodka)
# 182     (dr. mcgillicuddy's cherry schnapps)      (captain morgan spiced rum)
# 210                               (rumchata)      (captain morgan spiced rum)
# 205                     (malibu coconut rum)      (captain morgan spiced rum)
# 221              (uv blue (raspberry) vodka)      (captain morgan spiced rum)
# 217                       (southern comfort)      (captain morgan spiced rum)
# 60               (admiral nelson spiced rum)                  (hawkeye vodka)
# 180            (crown royal canadian whisky)      (captain morgan spiced rum)
# 199                                (jameson)      (captain morgan spiced rum)
# 82                    (bacardi superior rum)      (captain morgan spiced rum)
# 201                               (jim beam)      (captain morgan spiced rum)
# 196                   (jagermeister liqueur)      (captain morgan spiced rum)
# 401              (uv blue (raspberry) vodka)                  (hawkeye vodka)
# 212            (seagrams 7 crown bl whiskey)      (captain morgan spiced rum)
# 194          (jack daniels old #7 black lbl)      (captain morgan spiced rum)
# 6             (absolut swedish vodka 80 prf)      (captain morgan spiced rum)
# 342                              (five star)                  (hawkeye vodka)
# 202  (jose cuervo especial reposado tequila)      (captain morgan spiced rum)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 267            0.613778            0.801633  0.554859    0.904006  1.127705
# 411            0.680366            0.801633  0.613417    0.901598  1.124702
# 307            0.616710            0.820716  0.563972    0.914484  1.114251
# 182            0.613778            0.838536  0.570874    0.930099  1.109193
# 210            0.596725            0.838536  0.554633    0.929462  1.108434
# 205            0.680366            0.838536  0.630109    0.926132  1.104463
# 221            0.662321            0.838536  0.610485    0.921736  1.099219
# 217            0.678336            0.838536  0.625237    0.921721  1.099202
# 60             0.668231            0.839800  0.615582    0.921213  1.096943
# 180            0.765316            0.838536  0.703510    0.919241  1.096244
# 199            0.616079            0.838536  0.565731    0.918278  1.095096
# 82             0.721014            0.838536  0.660336    0.915843  1.092192
# 201            0.737571            0.838536  0.674050    0.913879  1.089849
# 196            0.728819            0.838536  0.665794    0.913525  1.089428
# 401            0.662321            0.839800  0.603537    0.911246  1.085075
# 212            0.768564            0.838536  0.698457    0.908781  1.083771
# 194            0.801633            0.838536  0.728503    0.908774  1.083762
# 6              0.763015            0.838536  0.692863    0.908059  1.082909
# 342            0.616710            0.839800  0.559957    0.907974  1.081179
# 202            0.721014            0.838536  0.653163    0.905894  1.080328
#
#      leverage  conviction
# 267  0.062834    2.066448
# 411  0.068013    2.015883
# 307  0.057828    2.096498
# 182  0.056199    2.309896
# 210  0.054258    2.289044
# 205  0.059597    2.185845
# 221  0.055104    2.063051
# 217  0.056427    2.062672
# 60   0.054403    2.033322
# 180  0.061764    1.999319
# 199  0.049127    1.975758
# 82   0.055739    1.918595
# 201  0.055570    1.874834
# 196  0.054653    1.867175
# 401  0.047320    1.804989
# 212  0.053988    1.770072
# 194  0.056304    1.769923
# 6    0.053047    1.756162
# 342  0.042044    1.740809
# 202  0.048566    1.715764

# %%
frequent_itemsets_liq.sort_values(by='support', ascending=False).head(20)
# Out:
#       support                                           itemsets
# 5    0.916358                                     (black velvet)
# 19   0.839800                                    (hawkeye vodka)
# 9    0.838536                        (captain morgan spiced rum)
# 16   0.820716                               (five o'clock vodka)
# 102  0.805332          (black velvet, captain morgan spiced rum)
# 112  0.804566                      (black velvet, hawkeye vodka)
# 22   0.801633                    (jack daniels old #7 black lbl)
# 109  0.783587                 (five o'clock vodka, black velvet)
# 113  0.771677      (jack daniels old #7 black lbl, black velvet)
# 34   0.768564                      (seagrams 7 crown bl whiskey)
# 11   0.765316                      (crown royal canadian whisky)
# 0    0.763015                     (absolut swedish vodka 80 prf)
# 14   0.755211                        (fireball cinnamon whiskey)
# 136  0.742624         (captain morgan spiced rum, hawkeye vodka)
# 123  0.742308        (seagrams 7 crown bl whiskey, black velvet)
# 25   0.737571                                         (jim beam)
# 42   0.736308       (black velvet, absolut swedish vodka 80 prf)
# 104  0.735270        (crown royal canadian whisky, black velvet)
# 23   0.728819                             (jagermeister liqueur)
# 137  0.728503  (jack daniels old #7 black lbl, captain morgan...

# %% [markdown]
# #### CONVENIENCE STORES

# %%
rules_conv, frequent_itemsets_conv = mba(store_t='Convenience Store')
rules_conv
# Out:
# Store Type
#                    antecedents                  consequents  \
# 0               (black velvet)  (admiral nelson spiced rum)
# 1  (admiral nelson spiced rum)               (black velvet)
# 2               (black velvet)  (captain morgan spiced rum)
# 3  (captain morgan spiced rum)               (black velvet)
# 4               (black velvet)              (hawkeye vodka)
# 5              (hawkeye vodka)               (black velvet)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.904569            0.538048  0.510445    0.564297  1.048786
# 1            0.538048            0.904569  0.510445    0.948699  1.048786
# 2            0.904569            0.615677  0.571931    0.632269  1.026949
# 3            0.615677            0.904569  0.571931    0.928946  1.026949
# 4            0.904569            0.660406  0.616394    0.681422  1.031824
# 5            0.660406            0.904569  0.616394    0.933356  1.031824
#
#    leverage  conviction
# 0  0.023744    1.060246
# 1  0.023744    1.860233
# 2  0.015009    1.045120
# 3  0.015009    1.343087
# 4  0.019011    1.065971
# 5  0.019011    1.431953

# %%
frequent_itemsets_conv.sort_values(by='support', ascending=False).head(20)
# Out:
#     support                                    itemsets
# 1  0.904569                              (black velvet)
# 5  0.660406                             (hawkeye vodka)
# 9  0.616394               (black velvet, hawkeye vodka)
# 2  0.615677                 (captain morgan spiced rum)
# 8  0.571931   (black velvet, captain morgan spiced rum)
# 0  0.538048                 (admiral nelson spiced rum)
# 7  0.510445   (black velvet, admiral nelson spiced rum)
# 3  0.507253                 (fireball cinnamon whiskey)
# 4  0.505964  (fireball cinnamon whiskey mini dispenser)
# 6  0.503570                                  (jim beam)

# %% [markdown]
# #### DRUG STORES

# %%
rules_drug, frequent_itemsets_drug = mba(store_t='Drug Store')
rules_drug_org.sort_values('lift', ascending = False)
# Out:
# Season
#                         antecedents                      consequents  \
# 6                    (black velvet)          (smirnoff vodka 80 prf)
# 7           (smirnoff vodka 80 prf)                   (black velvet)
# 2       (admiral nelson spiced rum)                  (hawkeye vodka)
# 3                   (hawkeye vodka)      (admiral nelson spiced rum)
# 11                  (hawkeye vodka)  (jack daniels old #7 black lbl)
# 10  (jack daniels old #7 black lbl)                  (hawkeye vodka)
# 12            (paramount white rum)                  (hawkeye vodka)
# 13                  (hawkeye vodka)            (paramount white rum)
# 17          (smirnoff vodka 80 prf)                  (hawkeye vodka)
# 16                  (hawkeye vodka)          (smirnoff vodka 80 prf)
# 15                  (hawkeye vodka)    (seagrams 7 crown bl whiskey)
# 14    (seagrams 7 crown bl whiskey)                  (hawkeye vodka)
# 8                   (hawkeye vodka)      (fireball cinnamon whiskey)
# 9       (fireball cinnamon whiskey)                  (hawkeye vodka)
# 18           (titos handmade vodka)                  (hawkeye vodka)
# 19                  (hawkeye vodka)           (titos handmade vodka)
# 1                   (hawkeye vodka)   (absolut swedish vodka 80 prf)
# 0    (absolut swedish vodka 80 prf)                  (hawkeye vodka)
# 5                   (hawkeye vodka)                   (black velvet)
# 4                    (black velvet)                  (hawkeye vodka)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 6             0.774796            0.611226  0.505357    0.652246  1.067111
# 7             0.611226            0.774796  0.505357    0.826793  1.067111
# 2             0.544972            0.907402  0.514892    0.944805  1.041220
# 3             0.907402            0.544972  0.514892    0.567436  1.041220
# 11            0.907402            0.546446  0.515777    0.568411  1.040195
# 10            0.546446            0.907402  0.515777    0.943875  1.040195
# 12            0.536125            0.907402  0.505554    0.942978  1.039206
# 13            0.907402            0.536125  0.505554    0.557144  1.039206
# 17            0.611226            0.907402  0.575936    0.942264  1.038420
# 16            0.907402            0.611226  0.575936    0.634709  1.038420
# 15            0.907402            0.575347  0.540450    0.595602  1.035205
# 14            0.575347            0.907402  0.540450    0.939347  1.035205
# 8             0.907402            0.559324  0.524427    0.577944  1.033291
# 9             0.559324            0.907402  0.524427    0.937610  1.033291
# 18            0.579475            0.907402  0.541335    0.934182  1.029512
# 19            0.907402            0.579475  0.541335    0.596577  1.029512
# 1             0.907402            0.559717  0.521872    0.575127  1.027532
# 0             0.559717            0.907402  0.521872    0.932385  1.027532
# 5             0.907402            0.774796  0.719847    0.793305  1.023889
# 4             0.774796            0.907402  0.719847    0.929079  1.023889
#
#     leverage  conviction
# 6   0.031782    1.117956
# 7   0.031782    1.300203
# 2   0.020384    1.677659
# 3   0.020384    1.051932
# 11  0.019930    1.050892
# 10  0.019930    1.649848
# 12  0.019073    1.623890
# 13  0.019073    1.047463
# 17  0.021309    1.603829
# 16  0.021309    1.064287
# 15  0.018380    1.050087
# 14  0.018380    1.526694
# 8   0.016896    1.044118
# 9   0.016896    1.484177
# 18  0.015518    1.406870
# 19  0.015518    1.042391
# 1   0.013983    1.036271
# 0   0.013983    1.369489
# 5   0.016795    1.089548
# 4   0.016795    1.305649

# %%
frequent_itemsets_drug.sort_values(by='support', ascending=False).head(20)
# Out:
#       support                                           itemsets
# 4    0.929878                                     (black velvet)
# 21   0.922866                                    (hawkeye vodka)
# 180  0.873171                      (black velvet, hawkeye vodka)
# 34   0.872561                              (mccormick vodka pet)
# 46   0.861280                      (seagrams 7 crown bl whiskey)
# 328  0.822866               (mccormick vodka pet, hawkeye vodka)
# 192  0.821646                (black velvet, mccormick vodka pet)
# 201  0.821037        (seagrams 7 crown bl whiskey, black velvet)
# 337  0.812805       (seagrams 7 crown bl whiskey, hawkeye vodka)
# 1    0.801829                        (admiral nelson spiced rum)
# 40   0.798780                              (paramount white rum)
# 431  0.771037  (seagrams 7 crown bl whiskey, mccormick vodka ...
# 9    0.768902                        (captain morgan spiced rum)
# 16   0.767073                               (five o'clock vodka)
# 26   0.766159                                         (jim beam)
# 89   0.764939          (black velvet, admiral nelson spiced rum)
# 96   0.763415         (admiral nelson spiced rum, hawkeye vodka)
# 33   0.761280                                  (mccormick vodka)
# 198  0.760366                (black velvet, paramount white rum)
# 334  0.758841               (paramount white rum, hawkeye vodka)

# %% [markdown]
# #### CASINOS

# %%
rules_cas, frequent_itemsets_cas = mba('Casino')
rules_cas.head(20)
# Not many casinos or data points
# Out:
# Store Type
#                         antecedents                      consequents  \
# 0    (absolut swedish vodka 80 prf)                   (barton vodka)
# 1                    (barton vodka)   (absolut swedish vodka 80 prf)
# 2    (absolut swedish vodka 80 prf)      (captain morgan spiced rum)
# 3       (captain morgan spiced rum)   (absolut swedish vodka 80 prf)
# 4     (crown royal canadian whisky)   (absolut swedish vodka 80 prf)
# 5    (absolut swedish vodka 80 prf)    (crown royal canadian whisky)
# 6                (grey goose vodka)   (absolut swedish vodka 80 prf)
# 7    (absolut swedish vodka 80 prf)               (grey goose vodka)
# 8   (jack daniels old #7 black lbl)   (absolut swedish vodka 80 prf)
# 9    (absolut swedish vodka 80 prf)  (jack daniels old #7 black lbl)
# 10           (bacardi superior rum)      (captain morgan spiced rum)
# 11      (captain morgan spiced rum)           (bacardi superior rum)
# 12    (crown royal canadian whisky)           (bacardi superior rum)
# 13           (bacardi superior rum)    (crown royal canadian whisky)
# 14               (grey goose vodka)           (bacardi superior rum)
# 15           (bacardi superior rum)               (grey goose vodka)
# 16  (jack daniels old #7 black lbl)           (bacardi superior rum)
# 17           (bacardi superior rum)  (jack daniels old #7 black lbl)
# 18  (jack daniels old #7 black lbl)  (bailey's original irish cream)
# 19  (bailey's original irish cream)  (jack daniels old #7 black lbl)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.682927            0.656504  0.510163    0.747024  1.137881
# 1             0.656504            0.682927  0.510163    0.777090  1.137881
# 2             0.682927            0.808943  0.573171    0.839286  1.037509
# 3             0.808943            0.682927  0.573171    0.708543  1.037509
# 4             0.839431            0.682927  0.591463    0.704600  1.031736
# 5             0.682927            0.839431  0.591463    0.866071  1.031736
# 6             0.782520            0.682927  0.556911    0.711688  1.042115
# 7             0.682927            0.782520  0.556911    0.815476  1.042115
# 8             0.819106            0.682927  0.577236    0.704715  1.031904
# 9             0.682927            0.819106  0.577236    0.845238  1.031904
# 10            0.646341            0.808943  0.554878    0.858491  1.061250
# 11            0.808943            0.646341  0.554878    0.685930  1.061250
# 12            0.839431            0.646341  0.569106    0.677966  1.048929
# 13            0.646341            0.839431  0.569106    0.880503  1.048929
# 14            0.782520            0.646341  0.560976    0.716883  1.109140
# 15            0.646341            0.782520  0.560976    0.867925  1.109140
# 16            0.819106            0.646341  0.579268    0.707196  1.094152
# 17            0.646341            0.819106  0.579268    0.896226  1.094152
# 18            0.819106            0.565041  0.508130    0.620347  1.097881
# 19            0.565041            0.819106  0.508130    0.899281  1.097881
#
#     leverage  conviction
# 0   0.061818    1.357819
# 1   0.061818    1.422425
# 2   0.020722    1.188799
# 3   0.020722    1.087889
# 4   0.018194    1.073371
# 5   0.018194    1.198916
# 6   0.022506    1.099758
# 7   0.022506    1.178600
# 8   0.017847    1.073786
# 9   0.017847    1.168856
# 10  0.032025    1.350136
# 11  0.032025    1.126049
# 12  0.026547    1.098203
# 13  0.026547    1.343710
# 14  0.055200    1.249161
# 15  0.055200    1.646632
# 16  0.049846    1.207834
# 17  0.049846    1.743163
# 18  0.045302    1.145677
# 19  0.045302    1.796022

# %%
frequent_itemsets_cas.sort_values(by='support', ascending=False).head(20)
# Out:
#      support                                           itemsets
# 6   0.839431                      (crown royal canadian whisky)
# 8   0.819106                    (jack daniels old #7 black lbl)
# 5   0.808943                        (captain morgan spiced rum)
# 7   0.782520                                 (grey goose vodka)
# 39  0.723577  (jack daniels old #7 black lbl, crown royal ca...
# 44  0.707317  (grey goose vodka, jack daniels old #7 black lbl)
# 34  0.697154  (jack daniels old #7 black lbl, captain morgan...
# 32  0.693089  (crown royal canadian whisky, captain morgan s...
# 38  0.689024    (grey goose vodka, crown royal canadian whisky)
# 0   0.682927                     (absolut swedish vodka 80 prf)
# 33  0.662602      (grey goose vodka, captain morgan spiced rum)
# 3   0.656504                                     (barton vodka)
# 14  0.654472                            (patron tequila silver)
# 1   0.646341                             (bacardi superior rum)
# 11  0.632114                         (ketel one imported vodka)
# 51  0.601626  (jack daniels old #7 black lbl, patron tequila...
# 20  0.591463  (crown royal canadian whisky, absolut swedish ...
# 49  0.581301  (jack daniels old #7 black lbl, ketel one impo...
# 26  0.579268  (jack daniels old #7 black lbl, bacardi superi...
# 22  0.577236  (jack daniels old #7 black lbl, absolut swedis...

# %% [markdown]
# ## SEASONS

# %%
df['Month'] = pd.DatetimeIndex(df.Date).month
# Out:
#                   Date Store Number                    Store Type  \
# 0  2012-05-03 00:00:00         2636          Liquor Tobacco Store
# 1  2012-07-05 00:00:00         3735          Liquor Tobacco Store
# 2  2012-03-06 00:00:00         4631                         Other
# 3  2013-08-26 00:00:00         3162  Other Grocery or Convenience
# 4  2015-08-12 00:00:00         2513                   Supermarket
#
#                         product_name category_new  Volume Sold      County
# 0                      nikolai vodka        vodka         21.0        polk
# 1              kessler blend whiskey       whisky          1.2    buchanan
# 2                      uv cake vodka        vodka          9.0  black hawk
# 3               windsor canadian pet       whisky         10.5   muscatine
# 4  captain morgan parrot bay coconut          rum          1.5     johnson

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Store Number            object
# Store Type              object
# product_name            object
# category_new            object
# Volume Sold            float64
# County                  object
# Month                    int64
# dtype: object

# %% [markdown]
# # SPRING

# %%
rules_sp, frequent_itemsets_sp = mba(season=[3,4,5])

# %%
rules_sp
# Out:
#                         antecedents                      consequents  \
# 0                    (black velvet)   (absolut swedish vodka 80 prf)
# 1    (absolut swedish vodka 80 prf)                   (black velvet)
# 2    (absolut swedish vodka 80 prf)                  (hawkeye vodka)
# 3                   (hawkeye vodka)   (absolut swedish vodka 80 prf)
# 4                    (black velvet)      (admiral nelson spiced rum)
# 5       (admiral nelson spiced rum)                   (black velvet)
# 6       (admiral nelson spiced rum)                  (hawkeye vodka)
# 7                   (hawkeye vodka)      (admiral nelson spiced rum)
# 8            (bacardi superior rum)                   (black velvet)
# 9                    (black velvet)           (bacardi superior rum)
# 10                   (black velvet)      (captain morgan spiced rum)
# 11      (captain morgan spiced rum)                   (black velvet)
# 12                   (black velvet)      (fireball cinnamon whiskey)
# 13      (fireball cinnamon whiskey)                   (black velvet)
# 14             (five o'clock vodka)                   (black velvet)
# 15                   (black velvet)             (five o'clock vodka)
# 16                   (black velvet)                  (hawkeye vodka)
# 17                  (hawkeye vodka)                   (black velvet)
# 18  (jack daniels old #7 black lbl)                   (black velvet)
# 19                   (black velvet)  (jack daniels old #7 black lbl)
# 20                   (black velvet)                       (jim beam)
# 21                       (jim beam)                   (black velvet)
# 22    (seagrams 7 crown bl whiskey)                   (black velvet)
# 23                   (black velvet)    (seagrams 7 crown bl whiskey)
# 24                   (black velvet)          (smirnoff vodka 80 prf)
# 25          (smirnoff vodka 80 prf)                   (black velvet)
# 26      (captain morgan spiced rum)                  (hawkeye vodka)
# 27                  (hawkeye vodka)      (captain morgan spiced rum)
# 28    (seagrams 7 crown bl whiskey)      (captain morgan spiced rum)
# 29      (captain morgan spiced rum)    (seagrams 7 crown bl whiskey)
# 30                  (hawkeye vodka)      (fireball cinnamon whiskey)
# 31      (fireball cinnamon whiskey)                  (hawkeye vodka)
# 32  (jack daniels old #7 black lbl)                  (hawkeye vodka)
# 33                  (hawkeye vodka)  (jack daniels old #7 black lbl)
# 34                  (hawkeye vodka)                       (jim beam)
# 35                       (jim beam)                  (hawkeye vodka)
# 36    (seagrams 7 crown bl whiskey)                  (hawkeye vodka)
# 37                  (hawkeye vodka)    (seagrams 7 crown bl whiskey)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.903051            0.595187  0.559977    0.620095  1.041848
# 1             0.595187            0.903051  0.559977    0.940842  1.041848
# 2             0.595187            0.779315  0.510414    0.857569  1.100414
# 3             0.779315            0.595187  0.510414    0.654952  1.100414
# 4             0.903051            0.613236  0.582782    0.645348  1.052364
# 5             0.613236            0.903051  0.582782    0.950339  1.052364
# 6             0.613236            0.779315  0.530153    0.864518  1.109330
# 7             0.779315            0.613236  0.530153    0.680281  1.109330
# 8             0.575304            0.903051  0.545509    0.948210  1.050007
# 9             0.903051            0.575304  0.545509    0.604073  1.050007
# 10            0.903051            0.682739  0.644549    0.713746  1.045416
# 11            0.682739            0.903051  0.644549    0.944064  1.045416
# 12            0.903051            0.595960  0.561753    0.622061  1.043797
# 13            0.595960            0.903051  0.561753    0.942602  1.043797
# 14            0.622862            0.903051  0.586735    0.941999  1.043129
# 15            0.903051            0.622862  0.586735    0.649726  1.043129
# 16            0.903051            0.779315  0.725226    0.803084  1.030499
# 17            0.779315            0.903051  0.725226    0.930593  1.030499
# 18            0.622891            0.903051  0.585876    0.940576  1.041553
# 19            0.903051            0.622891  0.585876    0.648774  1.041553
# 20            0.903051            0.619682  0.584959    0.647759  1.045308
# 21            0.619682            0.903051  0.584959    0.943967  1.045308
# 22            0.647185            0.903051  0.613236    0.947543  1.049269
# 23            0.903051            0.647185  0.613236    0.679071  1.049269
# 24            0.903051            0.553330  0.522160    0.578218  1.044977
# 25            0.553330            0.903051  0.522160    0.943668  1.044977
# 26            0.682739            0.779315  0.561352    0.822206  1.055037
# 27            0.779315            0.682739  0.561352    0.720315  1.055037
# 28            0.647185            0.682739  0.503395    0.777822  1.139267
# 29            0.682739            0.647185  0.503395    0.737317  1.139267
# 30            0.779315            0.595960  0.508122    0.652011  1.094051
# 31            0.595960            0.779315  0.508122    0.852610  1.094051
# 32            0.622891            0.779315  0.524022    0.841275  1.079505
# 33            0.779315            0.622891  0.524022    0.672414  1.079505
# 34            0.779315            0.619682  0.526056    0.675024  1.089307
# 35            0.619682            0.779315  0.526056    0.848914  1.089307
# 36            0.647185            0.779315  0.553932    0.855910  1.098284
# 37            0.779315            0.647185  0.553932    0.710793  1.098284
#
#     leverage  conviction
# 0   0.022493    1.065563
# 1   0.022493    1.638822
# 2   0.046576    1.549417
# 3   0.046576    1.173207
# 4   0.028998    1.090544
# 5   0.028998    1.952202
# 6   0.052249    1.628881
# 7   0.052249    1.209699
# 8   0.025980    1.871952
# 9   0.025980    1.072663
# 10  0.028001    1.108322
# 11  0.028001    1.733225
# 12  0.023571    1.069062
# 13  0.023571    1.689054
# 14  0.024259    1.671503
# 15  0.024259    1.076693
# 16  0.021464    1.120703
# 17  0.021464    1.396824
# 18  0.023374    1.631472
# 19  0.023374    1.073694
# 20  0.025355    1.079709
# 21  0.025355    1.730201
# 22  0.028795    1.848164
# 23  0.028795    1.099355
# 24  0.022474    1.059005
# 25  0.022474    1.721021
# 26  0.029283    1.241241
# 27  0.029283    1.134350
# 28  0.061536    1.427960
# 29  0.061536    1.343120
# 30  0.043681    1.161069
# 31  0.043681    1.497287
# 32  0.038594    1.390358
# 33  0.038594    1.151176
# 34  0.043129    1.170295
# 35  0.043129    1.460652
# 36  0.049571    1.531572
# 37  0.049571    1.219940

# %%
frequent_itemsets_sp.sort_values(by='support', ascending=False).head(20)
# Out:
#      support                                       itemsets
# 3   0.903051                                 (black velvet)
# 8   0.779315                                (hawkeye vodka)
# 26  0.725226                  (black velvet, hawkeye vodka)
# 4   0.682739                    (captain morgan spiced rum)
# 14  0.647185                  (seagrams 7 crown bl whiskey)
# 23  0.644549      (black velvet, captain morgan spiced rum)
# 9   0.622891                (jack daniels old #7 black lbl)
# 7   0.622862                           (five o'clock vodka)
# 11  0.619682                                     (jim beam)
# 1   0.613236                    (admiral nelson spiced rum)
# 29  0.613236    (seagrams 7 crown bl whiskey, black velvet)
# 6   0.595960                    (fireball cinnamon whiskey)
# 0   0.595187                 (absolut swedish vodka 80 prf)
# 25  0.586735             (five o'clock vodka, black velvet)
# 27  0.585876  (jack daniels old #7 black lbl, black velvet)
# 28  0.584959                       (black velvet, jim beam)
# 20  0.582782      (black velvet, admiral nelson spiced rum)
# 2   0.575304                         (bacardi superior rum)
# 24  0.561753      (black velvet, fireball cinnamon whiskey)
# 31  0.561352     (captain morgan spiced rum, hawkeye vodka)

# %% [markdown]
# # SUMMER

# %%
rules_su, frequent_itemsets_su = mba(season=[6,7,8])
rules_su
# Out:
# Season
#                         antecedents                      consequents  \
# 0                    (black velvet)   (absolut swedish vodka 80 prf)
# 1    (absolut swedish vodka 80 prf)                   (black velvet)
# 2    (absolut swedish vodka 80 prf)                  (hawkeye vodka)
# 3                   (hawkeye vodka)   (absolut swedish vodka 80 prf)
# 4                    (black velvet)      (admiral nelson spiced rum)
# 5       (admiral nelson spiced rum)                   (black velvet)
# 6       (admiral nelson spiced rum)                  (hawkeye vodka)
# 7                   (hawkeye vodka)      (admiral nelson spiced rum)
# 8                    (black velvet)           (bacardi superior rum)
# 9            (bacardi superior rum)                   (black velvet)
# 10           (bacardi superior rum)                  (hawkeye vodka)
# 11                  (hawkeye vodka)           (bacardi superior rum)
# 12                   (black velvet)      (captain morgan spiced rum)
# 13      (captain morgan spiced rum)                   (black velvet)
# 14                   (black velvet)      (fireball cinnamon whiskey)
# 15      (fireball cinnamon whiskey)                   (black velvet)
# 16                   (black velvet)             (five o'clock vodka)
# 17             (five o'clock vodka)                   (black velvet)
# 18                   (black velvet)                  (hawkeye vodka)
# 19                  (hawkeye vodka)                   (black velvet)
# 20  (jack daniels old #7 black lbl)                   (black velvet)
# 21                   (black velvet)  (jack daniels old #7 black lbl)
# 22                   (black velvet)           (jagermeister liqueur)
# 23           (jagermeister liqueur)                   (black velvet)
# 24                   (black velvet)                       (jim beam)
# 25                       (jim beam)                   (black velvet)
# 26                   (black velvet)             (malibu coconut rum)
# 27             (malibu coconut rum)                   (black velvet)
# 28    (seagrams 7 crown bl whiskey)                   (black velvet)
# 29                   (black velvet)    (seagrams 7 crown bl whiskey)
# 30                   (black velvet)          (smirnoff vodka 80 prf)
# 31          (smirnoff vodka 80 prf)                   (black velvet)
# 32                   (black velvet)      (uv blue (raspberry) vodka)
# 33      (uv blue (raspberry) vodka)                   (black velvet)
# 34      (captain morgan spiced rum)                  (hawkeye vodka)
# 35                  (hawkeye vodka)      (captain morgan spiced rum)
# 36                  (hawkeye vodka)      (fireball cinnamon whiskey)
# 37      (fireball cinnamon whiskey)                  (hawkeye vodka)
# 38  (jack daniels old #7 black lbl)                  (hawkeye vodka)
# 39                  (hawkeye vodka)  (jack daniels old #7 black lbl)
# 40                  (hawkeye vodka)                       (jim beam)
# 41                       (jim beam)                  (hawkeye vodka)
# 42    (seagrams 7 crown bl whiskey)                  (hawkeye vodka)
# 43                  (hawkeye vodka)    (seagrams 7 crown bl whiskey)
# 44                  (hawkeye vodka)          (smirnoff vodka 80 prf)
# 45          (smirnoff vodka 80 prf)                  (hawkeye vodka)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.891968            0.627283  0.586701    0.657760  1.048586
# 1             0.627283            0.891968  0.586701    0.935305  1.048586
# 2             0.627283            0.788966  0.539795    0.860529  1.090704
# 3             0.788966            0.627283  0.539795    0.684181  1.090704
# 4             0.891968            0.615002  0.580012    0.650262  1.057332
# 5             0.615002            0.891968  0.580012    0.943107  1.057332
# 6             0.615002            0.788966  0.537378    0.873783  1.107504
# 7             0.788966            0.615002  0.537378    0.681117  1.107504
# 8             0.891968            0.601962  0.566719    0.635358  1.055480
# 9             0.601962            0.891968  0.566719    0.941454  1.055480
# 10            0.601962            0.788966  0.521078    0.865633  1.097174
# 11            0.788966            0.601962  0.521078    0.660457  1.097174
# 12            0.891968            0.678264  0.636052    0.713088  1.051343
# 13            0.678264            0.891968  0.636052    0.937764  1.051343
# 14            0.891968            0.605390  0.568181    0.636997  1.052208
# 15            0.605390            0.891968  0.568181    0.938536  1.052208
# 16            0.891968            0.618262  0.580574    0.650892  1.052776
# 17            0.618262            0.891968  0.580574    0.939043  1.052776
# 18            0.891968            0.788966  0.727812    0.815962  1.034216
# 19            0.788966            0.891968  0.727812    0.922488  1.034216
# 20            0.635490            0.891968  0.594851    0.936052  1.049423
# 21            0.891968            0.635490  0.594851    0.666898  1.049423
# 22            0.891968            0.533556  0.503597    0.564591  1.058166
# 23            0.533556            0.891968  0.503597    0.943850  1.058166
# 24            0.891968            0.618346  0.582036    0.652530  1.055283
# 25            0.618346            0.891968  0.582036    0.941278  1.055283
# 26            0.891968            0.535748  0.506492    0.567837  1.059894
# 27            0.535748            0.891968  0.506492    0.945392  1.059894
# 28            0.643809            0.891968  0.608257    0.944779  1.059208
# 29            0.891968            0.643809  0.608257    0.681927  1.059208
# 30            0.891968            0.586448  0.550334    0.616989  1.052078
# 31            0.586448            0.891968  0.550334    0.938420  1.052078
# 32            0.891968            0.549519  0.517959    0.580692  1.056727
# 33            0.549519            0.891968  0.517959    0.942566  1.056727
# 34            0.678264            0.788966  0.564415    0.832146  1.054729
# 35            0.788966            0.678264  0.564415    0.715385  1.054729
# 36            0.788966            0.605390  0.520375    0.659566  1.089489
# 37            0.605390            0.788966  0.520375    0.859570  1.089489
# 38            0.635490            0.788966  0.539964    0.849682  1.076955
# 39            0.788966            0.635490  0.539964    0.684394  1.076955
# 40            0.788966            0.618346  0.529594    0.671250  1.085557
# 41            0.618346            0.788966  0.529594    0.856468  1.085557
# 42            0.643809            0.788966  0.556489    0.864371  1.095573
# 43            0.788966            0.643809  0.556489    0.705340  1.095573
# 44            0.788966            0.586448  0.508122    0.644035  1.098196
# 45            0.586448            0.788966  0.508122    0.866440  1.098196
#
#     leverage  conviction
# 0   0.027184    1.089052
# 1   0.027184    1.669860
# 2   0.044890    1.513097
# 3   0.044890    1.180157
# 4   0.031450    1.100817
# 5   0.031450    1.898849
# 6   0.052163    1.671995
# 7   0.052163    1.207334
# 8   0.029789    1.091587
# 9   0.029789    1.845248
# 10  0.046151    1.570580
# 11  0.046151    1.172276
# 12  0.031062    1.121376
# 13  0.031062    1.735851
# 14  0.028192    1.087069
# 15  0.028192    1.757644
# 16  0.029105    1.093466
# 17  0.029105    1.772259
# 18  0.024079    1.146685
# 19  0.024079    1.393744
# 20  0.028015    1.689366
# 21  0.028015    1.094289
# 22  0.027682    1.071278
# 23  0.027682    1.924006
# 24  0.030491    1.098379
# 25  0.030491    1.839724
# 26  0.028622    1.074250
# 27  0.028622    1.978306
# 28  0.034000    1.956364
# 29  0.034000    1.119842
# 30  0.027241    1.079739
# 31  0.027241    1.754324
# 32  0.027805    1.074343
# 33  0.027805    1.880991
# 34  0.029287    1.257242
# 35  0.029287    1.130424
# 36  0.042743    1.159137
# 37  0.042743    1.502769
# 38  0.038584    1.403911
# 39  0.038584    1.154954
# 40  0.041739    1.160923
# 41  0.041739    1.470286
# 42  0.048546    1.555957
# 43  0.048546    1.208820
# 44  0.045434    1.161777
# 45  0.045434    1.580064

# %%
frequent_itemsets_su.sort_values(by='support', ascending=False).head(20)
# Out:
#      support                                       itemsets
# 3   0.891968                                 (black velvet)
# 8   0.788966                                (hawkeye vodka)
# 28  0.727812                  (black velvet, hawkeye vodka)
# 4   0.678264                    (captain morgan spiced rum)
# 14  0.643809                  (seagrams 7 crown bl whiskey)
# 25  0.636052      (black velvet, captain morgan spiced rum)
# 9   0.635490                (jack daniels old #7 black lbl)
# 0   0.627283                 (absolut swedish vodka 80 prf)
# 11  0.618346                                     (jim beam)
# 7   0.618262                           (five o'clock vodka)
# 1   0.615002                    (admiral nelson spiced rum)
# 33  0.608257    (seagrams 7 crown bl whiskey, black velvet)
# 6   0.605390                    (fireball cinnamon whiskey)
# 2   0.601962                         (bacardi superior rum)
# 29  0.594851  (jack daniels old #7 black lbl, black velvet)
# 19  0.586701   (black velvet, absolut swedish vodka 80 prf)
# 15  0.586448                        (smirnoff vodka 80 prf)
# 31  0.582036                       (black velvet, jim beam)
# 27  0.580574             (black velvet, five o'clock vodka)
# 21  0.580012      (black velvet, admiral nelson spiced rum)

# %%
df.head()
# Out:
#         Date Store Number                    Store Type  \
# 0 2012-05-03         2636          Liquor Tobacco Store
# 1 2012-07-05         3735          Liquor Tobacco Store
# 2 2012-03-06         4631                         Other
# 3 2013-08-26         3162  Other Grocery or Convenience
# 4 2015-08-12         2513                   Supermarket
#
#                         product_name category_new  Volume Sold      County  \
# 0                      nikolai vodka        vodka         21.0        polk
# 1              kessler blend whiskey       whisky          1.2    buchanan
# 2                      uv cake vodka        vodka          9.0  black hawk
# 3               windsor canadian pet       whisky         10.5   muscatine
# 4  captain morgan parrot bay coconut          rum          1.5     johnson
#
#    Month
# 0      5
# 1      7
# 2      3
# 3      8
# 4      8

# %% [markdown]
# ## NOTES

# %% [markdown]
# - Support: Its the default popularity of an item. In mathematical terms, the support of item A is nothing but the ratio of transactions involving A to the total number of transactions.
#
# -- Support(Grapes) = (Transactions involving Grapes)/(Total transaction)
#
# - Confidence: Likelihood that customer who bought both A and B. Its divides the number of transactions involving both A and B by the number of transactions involving B.
#
# -- Confidence(A => B) = (Transactions involving both A and B)/(Transactions involving only A)

# %% [markdown]
# The support value for the first rule is 0.003. This number is calculated by dividing the number of transactions containing ‘avocado,’ ‘spaghetti,’ and ‘milk’ by the total number of transactions.
#
# The confidence level for the rule is 0.416, which shows that out of all the transactions that contain both ‘avocado’ and ‘spaghetti’, 41.6 percent contain ‘milk’ too.
#
# The lift of 1.241 tells us that ‘milk’ is 1.241 times more likely to be bought by the customers who buy both ‘avocado’ and ‘spaghetti’ compared to the default likelihood sale of ‘milk.’

# %% [markdown]
# # Downsampling Test

# %% [markdown]
# ### Test sampling code

# %%
clean.loc[:,:] = clean.reset_index()

# %%
samp_size = int(1e5)

# %%
np.random.seed(7)
clean_rand = np.random.choice(clean.index, size=samp_size, replace=False)

# %%
clean_rand.sort()

# %%
clean_rand.max()
# Out:
# 27372181

# %%
clean.shape
# Out:
# (27373000, 24)

# %%
clean.iloc[clean_rand]
# Out:
#                Date Store Number Vendor Number Item Number  State Bottle Cost  \
# 20       2015-02-12         3456         259.0       18120              14.97
# 586      2012-10-30         4500          35.0       43126               7.53
# 839      2014-08-29         3612         434.0       41846               9.00
# 919      2012-02-02         2637         301.0       38176               9.64
# 1279     2012-05-17         2579         115.0       11776               5.23
# ...             ...          ...           ...         ...                ...
# 27371496 2012-10-02         2616         260.0       25606               6.53
# 27371524 2014-06-03         4239         260.0       10008              10.50
# 27371718 2014-05-01         3565         259.0       35416               4.84
# 27372036 2013-04-17         3013         205.0       52596               5.75
# 27372181 2014-03-13         2587         370.0       67524               6.49
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 20                      22.46             1           22.46
# 586                     11.30             6           67.80
# 839                     13.50             2           27.00
# 919                     14.46             4           57.84
# 1279                     7.84            12           94.08
# ...                       ...           ...             ...
# 27371496                 9.79            12          117.48
# 27371524                15.74             6           94.44
# 27371718                 7.26            12           87.12
# 27372036                 8.62             3           25.86
# 27372181                 9.74             1            9.74
#
#           Volume Sold (Liters)                                   Store Name  \
# 20                        0.75                      quick shop / clear lake
# 586                       4.50  casey's general store #2788 / north liberty
# 839                       1.50                   b and c liquor / maquoketa
# 919                       3.00                        hy-vee #5 / davenport
# 1279                      9.00                 hy-vee food store / grinnell
# ...                        ...                                          ...
# 27371496                  9.00               hy-vee food and drug / clinton
# 27371524                 10.50            fareway stores #850 / spirit lake
# 27371718                  9.00                        hartig drug store #10
# 27372036                  2.25                                keith's foods
# 27372181                  0.38                 hy-vee food store / johnston
#
#                         Address           City Zip Code  \
# 20                 904 n 8th st     clear lake    50428
# 586            595 n kansas ave  north liberty    52317
# 839                 509 e platt      maquoketa    52060
# 919               2351 w locust      davenport    52804
# 1279      320 west street south       grinnell    50112
# ...                         ...            ...      ...
# 27371496       901 south 4th st        clinton    52732
# 27371524            1906 keokuk    spirit lake    51360
# 27371718   701 mormon trek blvd      iowa city    52246
# 27372036        207 e locust st     bloomfield    52537
# 27372181    5750 merle hay road       johnston    50131
#
#                                  Store Location County Number      County  \
# 20                 POINT (-93.378772 43.142868)          17.0  cerro gord
# 586                POINT (-91.636952 41.751925)          52.0     johnson
# 839        POINT (-90.659692 42.06922000000001)          49.0     jackson
# 919                POINT (-90.611972 41.538207)           NaN         NaN
# 1279                 POINT (-92.727343 41.7283)          79.0   poweshiek
# ...                                         ...           ...         ...
# 27371496  POINT (-90.193204 41.836268000000004)          23.0     clinton
# 27371524            POINT (-95.106219 43.42157)          30.0   dickinson
# 27371718           POINT (-91.574025 41.651984)          52.0     johnson
# 27372036           POINT (-92.412847 40.752691)          26.0       davis
# 27372181           POINT (-93.697731 41.665172)          77.0        polk
#
#                             Store Type category_id  \
# 20                   Convenience Store   1011250.0
# 586                  Convenience Store   1062200.0
# 839               Liquor Tobacco Store   1101100.0
# 919                        Supermarket   1031100.0
# 1279                       Supermarket   1012100.0
# ...                                ...         ...
# 27371496                    Drug Store   1011100.0
# 27371524                   Supermarket   1012200.0
# 27371718                    Drug Store   1031080.0
# 27372036  Other Grocery or Convenience   1051010.0
# 27372181                   Supermarket   1081030.0
#
#                              category_name                 product_name  \
# 20          single barrel bourbon whiskies        evan williams vintage
# 586       puerto rico & virgin islands rum         bacardi superior rum
# 839                       american alcohol            everclear alcohol
# 919                        american vodkas         titos handmade vodka
# 1279                     canadian whiskies                 black velvet
# ...                                    ...                          ...
# 27371496                  blended whiskies  seagrams 7 crown bl whiskey
# 27371524                   scotch whiskies         scoresby rare scotch
# 27371718                    vodka 80 proof       burnett's vodka 80 prf
# 27372036           american grape brandies                     e & j vs
# 27372181                   coffee liqueurs        kahlua coffee liqueur
#
#           bottle_vol_ml  proof category_new  imported
# 20                750.0   86.0       whisky  domestic
# 586               750.0   80.0          rum  domestic
# 839               750.0  151.0        other  domestic
# 919               750.0   80.0        vodka  domestic
# 1279              750.0   80.0       whisky  domestic
# ...                 ...    ...          ...       ...
# 27371496          750.0   80.0       whisky  domestic
# 27371524         1750.0   80.0       whisky  domestic
# 27371718          750.0   80.0        vodka  domestic
# 27372036          750.0   80.0       brandy  domestic
# 27372181          375.0   40.0      liqueur  domestic
#
# [100000 rows x 24 columns]
